# %%
import numpy as np
import pathlib
import tensorflow as tf
import tensorflow_datasets as tfds
import zipfile
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.models import Model

# %%
MODEL_ALPHA = 0.35
MODEL_INPUT_WIDTH = 48
MODEL_INPUT_HEIGHT = 48
TFL_MODEL_FILE = "object_recognition.tflite"
TFL_MODEL_HEADER_FILE = "object_recognition_model.h"
TF_MODEL = "object_recognition"

# %%
with zipfile.ZipFile("MyDataset.zip", 'r') as zip_ref:
    zip_ref.extractall(".")
data_dir = "MyDataset"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  interpolation="bilinear",
  image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT)
  )

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  interpolation="bilinear",
  image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT)
  )
# Out:
# Found 80 files belonging to 3 classes.
# Using 64 files for training.
# Found 80 files belonging to 3 classes.
# Using 16 files for validation.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['Ball', 'Mag', 'Unknown']

# %%
rescale = tf.keras.layers.Rescaling(1./255, offset= -1)
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
val_ds   = val_ds.map(lambda x, y: (rescale(x), y))

# %%
# https://github.com/keras-team/keras-applications/blob/master/keras_applications/mobilenet_v2.py
base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
                         include_top=False,
                         weights='imagenet',
                         alpha=0.35)
base_model.trainable = False

feat_extr = base_model
# Out:
# /tmp/ipython-input-3994110907.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2019640/2019640 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
augmen = tf.keras.Sequential([
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomFlip('horizontal'),
])

train_ds = train_ds.map(lambda x, y: (augmen(x), y))
val_ds   = val_ds.map(lambda x, y: (augmen(x), y))

# %%
global_avg_layer = tf.keras.layers.GlobalAveragePooling2D()
dense_layer = tf.keras.layers.Dense(num_classes, activation='softmax')

# %%
inputs = tf.keras.Input(shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3))
x = global_avg_layer(feat_extr.layers[-1].output)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = dense_layer(x)
model = tf.keras.Model(inputs=feat_extr.inputs, outputs=outputs)

# %%
lr = 0.0005
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=False),
  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 24, 24,    │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 24, 24,    │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 24, 24,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │        144 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │        128 │ expanded_conv_de… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 24, 24,    │        384 │ expanded_conv_pr… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 24, 24,    │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 24, 24,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 25, 25,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 12, 12,    │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 12, 12, 8) │        384 │ block_1_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 12, 12, 8) │         32 │ block_1_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 12, 12,    │        384 │ block_1_project_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 12, 12,    │        192 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 12, 12,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 12, 12,    │        432 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │        192 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 12, 12, 8) │        384 │ block_2_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 12, 12, 8) │         32 │ block_2_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 12, 12, 8) │          0 │ block_1_project_… │
# │                     │                   │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 12, 12,    │        384 │ block_2_add[0][0] │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 12, 12,    │        192 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 12, 12,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 13, 13,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 6, 6, 48)  │        432 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │        192 │ block_3_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │          0 │ block_3_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 6, 6, 16)  │        768 │ block_3_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 6, 6, 16)  │         64 │ block_3_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 6, 6, 96)  │      1,536 │ block_3_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_4_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 6, 6, 96)  │          0 │ block_4_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 6, 6, 96)  │        864 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_4_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_4_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 6, 6, 16)  │      1,536 │ block_4_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 6, 6, 16)  │         64 │ block_4_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 6, 6, 16)  │          0 │ block_3_project_… │
# │                     │                   │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 6, 6, 96)  │      1,536 │ block_4_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_5_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 6, 6, 96)  │          0 │ block_5_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 6, 6, 96)  │        864 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_5_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_5_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 6, 6, 16)  │      1,536 │ block_5_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 6, 6, 16)  │         64 │ block_5_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None,
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6354 - loss: 0.8680 - val_accuracy: 0.5625 - val_loss: 1.2446
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5417 - loss: 1.0176 - val_accuracy: 0.5625 - val_loss: 0.9780
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6458 - loss: 0.8245 - val_accuracy: 0.6250 - val_loss: 1.4360

# %%
model.export(TF_MODEL)
# Out:
# Saved artifact at 'object_recognition'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 48, 48, 3), dtype=tf.float32, name='keras_tensor')]
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   138024215530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215532496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215533456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215536144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215538448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215538640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215539216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215539408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215540944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215540368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215540560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215540752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215539600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215541904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215541520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215541712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215542864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215543248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215543440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215542672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215543632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215540176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215542480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215543056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024215542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024212937040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213851280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213851664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213854352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213855696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213855888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213856080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213855504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152220880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152221072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024213854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152220496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152220688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152220304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152221456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152221648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152221840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152219920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152223376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152223760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152224912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152224528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152224720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152225680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152223184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152225104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152229328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153121232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024152234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153121040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153123536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153123728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153123920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153125072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153124880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153125456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153125648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153123344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153124304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153127952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153125264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153129872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138024153132752: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
with zipfile.ZipFile("TestDataset.zip", 'r') as zip_ref:
    zip_ref.extractall(".")
test_dir = "TestDataset"

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir,
                                                      interpolation="bilinear",
                                                      image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT))
test_ds  = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 37 files belonging to 3 classes.

# %%
repr_ds = test_ds.unbatch()

def representative_data_gen():
  for i_value, o_value in repr_ds.batch(1).take(48):
    yield [i_value]

converter = tf.lite.TFLiteConverter.from_saved_model(TF_MODEL)
converter.representative_dataset = tf.lite.RepresentativeDataset(representative_data_gen)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8

tfl_model = converter.convert()

# %%
size_tfl_model = len(tfl_model)
print(len(tfl_model), "bytes")
# Out:
# 619840 bytes

# %%
# Initialize the TFLite interpreter
interpreter = tf.lite.Interpreter(model_content=tfl_model)

# Allocate the tensors
interpreter.allocate_tensors()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# Get input/output layer information
i_details = interpreter.get_input_details()[0]
o_details = interpreter.get_output_details()[0]

# Get input quantization parameters.
i_quant = i_details["quantization_parameters"]
i_scale      = i_quant['scales'][0]
i_zero_point = i_quant['zero_points'][0]

# %%
test_ds0 = val_ds.unbatch()

num_correct_samples = 0
num_total_samples   = len(list(test_ds0.batch(1)))

for i_value, o_value in test_ds0.batch(1):
  i_value = (i_value / i_scale) + i_zero_point
  i_value = tf.cast(i_value, dtype=tf.int8)
  interpreter.set_tensor(i_details["index"], i_value)
  interpreter.invoke()
  o_pred = interpreter.get_tensor(o_details["index"])[0]

  if np.argmax(o_pred) == o_value:
    num_correct_samples += 1

print("Accuracy:", num_correct_samples/num_total_samples)
# Out:
# Accuracy: 0.5

# %%
open("object_recognition_model.tflite", "wb").write(tfl_model)
# !apt-get update && apt-get -qq install xxd
# !xxd -c 60 -i object_recognition_model.tflite > object_recognition.h
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
